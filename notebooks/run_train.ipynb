# %% [markdown]
# # Setup

# %%
# !nvidia-smi
# Out:
# Thu Jul 20 08:52:27 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla T4            Off  | 00000000:00:05.0 Off |                    0 |
# | N/A   41C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install --upgrade --quiet pip

# %%
# !pip install --upgrade --quiet transformers datasets sentencepiece tqdm accelerate huggingface-hub bitsandbytes

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Login to HuggingFace

# %%
# !git config --global credential.helper store

# %%
from huggingface_hub import login,

token = f"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"
login(token=token, add_to_git_credential=True)
# Out:
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Import dependencies

# %%
import numpy as np
import os

from evaluate import load

from torch import Tensor, bfloat16

from transformers import (
    DataCollatorForSeq2Seq,
    EarlyStoppingCallback,
    Trainer,
    TrainingArguments,
    T5ForConditionalGeneration,
    T5TokenizerFast,
)
from datasets import (
    DatasetDict,
    load_dataset,
)

# %% [markdown]
# # Load pre-processed dataset

# %%
train = load_dataset("rusano/ELI5_custom_encoded", split="train")
# Out:
# Downloading readme:   0%|          | 0.00/637 [00:00<?, ?B/s]
# Downloading and preparing dataset None/None to /root/.cache/huggingface/datasets/rusano___parquet/rusano--ELI5_custom_encoded-28a2d918684a2bd1/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/60.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/60.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/979k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/30.1M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/196296 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1507 [00:00<?, ? examples/s]
# Generating val split:   0%|          | 0/49074 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/rusano___parquet/rusano--ELI5_custom_encoded-28a2d918684a2bd1/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7. Subsequent calls will reuse this data.

# %%
train.set_format(type="torch")

# %% [markdown]
# # Fine-tune Setup

# %%
CHECKPOINT = "google/t5-v1_1-base"

MODEL = T5ForConditionalGeneration.from_pretrained(
    CHECKPOINT, return_dict=True, torch_dtype=bfloat16
)
TOKENIZER = T5TokenizerFast.from_pretrained("t5-base")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]

# %%
training_args = TrainingArguments(
    run_name="Teli5",
    output_dir="./checkpoints",
    overwrite_output_dir=True,
    per_device_train_batch_size=8,
    learning_rate=1e-4,
    weight_decay=1e-2,
    num_train_epochs=3,
    log_level="info",
    logging_dir="./logs",
    logging_strategy="steps",
    logging_steps=100,
    save_strategy="steps",
    save_steps=100,
    save_total_limit=10,
    save_safetensors=True,
    fp16=True,
    report_to="none",
    push_to_hub=True,
    hub_model_id="rusano/Teli5",
    # gradient_checkpointing=True,
    auto_find_batch_size=True,
)

# %%
ignore_pad_token_for_loss = True
label_pad_token_id = -100 if ignore_pad_token_for_loss else TOKENIZER.pad_token_id
DATA_COLLATOR = DataCollatorForSeq2Seq(
    TOKENIZER,
    model=MODEL,
    label_pad_token_id=label_pad_token_id,
    pad_to_multiple_of=None,
)

# %%
metric = load("glue", "mrpc")


def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)
# Out:
# Downloading builder script:   0%|          | 0.00/5.75k [00:00<?, ?B/s]

# %% [markdown]
# # Fine-tune START

# %%
trainer = Trainer(
    model=MODEL,
    args=training_args,
    train_dataset=train,
    data_collator=DATA_COLLATOR,
)

# Training
trainer.train()
# Out:
# Cloning https://huggingface.co/rusano/Teli5 into local empty directory.
# ***** Running training *****
#   Num examples = 100,000
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Training with DataParallel so batch size has been adjusted to: 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 18,750
#   Number of trainable parameters = 247,577,856
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='8542' max='18750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 8542/18750 5:49:37 < 6:57:54, 0.41 it/s, Epoch 1.37/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>35.578700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>28.258700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>25.241300</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>23.466200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>22.693800</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>21.760000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>21.471300</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>20.898700</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>19.191900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>18.485000</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>17.977500</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>17.694400</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>17.565000</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>16.664400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>15.842500</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>15.316300</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>14.914400</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>14.997500</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>14.660600</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>14.122500</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>13.523100</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>13.236900</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>13.113100</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>12.728700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>12.716900</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>12.520600</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>12.335000</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>12.176200</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>11.920000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>11.508700</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>11.100600</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>10.874400</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>10.730000</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>10.608100</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>10.543100</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>10.423100</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>10.425000</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>10.331300</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>10.243800</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>10.209400</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>10.181300</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>10.117500</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>10.176200</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>10.082500</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>10.039400</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>10.021900</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>10.046900</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>9.955600</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>9.907500</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>9.913800</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>9.875000</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>9.902500</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>9.818100</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>9.813800</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>9.842500</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>9.783100</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>9.786300</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>9.701900</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>9.810600</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>9.754400</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>9.764400</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>9.751900</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>9.659400</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>9.690600</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>9.675000</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>9.710000</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>9.669400</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>9.736900</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>9.699400</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>9.635000</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>9.570600</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>9.645600</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>9.563100</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>9.603700</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>9.554400</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>9.569400</td>
#     </tr>
#     <tr>
#       <td>7700</td>
#       <td>9.500000</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>9.493100</td>
#     </tr>
#     <tr>
#       <td>7900</td>
#       <td>9.531200</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>9.508700</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>9.505600</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>9.508100</td>
#     </tr>
#     <tr>
#       <td>8300</td>
#       <td>9.451900</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>9.552500</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>9.448800</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./checkpoints/checkpoint-100
# Configuration saved in ./checkpoints/checkpoint-100/config.json
# Configuration saved in ./checkpoints/checkpoint-100/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-100/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-200
# Configuration saved in ./checkpoints/checkpoint-200/config.json
# Configuration saved in ./checkpoints/checkpoint-200/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-200/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-300
# Configuration saved in ./checkpoints/checkpoint-300/config.json
# Configuration saved in ./checkpoints/checkpoint-300/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-300/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-400
# Configuration saved in ./checkpoints/checkpoint-400/config.json
# Configuration saved in ./checkpoints/checkpoint-400/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-400/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-500
# Configuration saved in ./checkpoints/checkpoint-500/config.json
# Configuration saved in ./checkpoints/checkpoint-500/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-600
# Configuration saved in ./checkpoints/checkpoint-600/config.json
# Configuration saved in ./checkpoints/checkpoint-600/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-600/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-700
# Configuration saved in ./checkpoints/checkpoint-700/config.json
# Configuration saved in ./checkpoints/checkpoint-700/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-700/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-800
# Configuration saved in ./checkpoints/checkpoint-800/config.json
# Configuration saved in ./checkpoints/checkpoint-800/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-800/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-900
# Configuration saved in ./checkpoints/checkpoint-900/config.json
# Configuration saved in ./checkpoints/checkpoint-900/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-900/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-1000
# Configuration saved in ./checkpoints/checkpoint-1000/config.json
# Configuration saved in ./checkpoints/checkpoint-1000/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to ./checkpoints/checkpoint-1100
# Configuration saved in ./checkpoints/checkpoint-1100/config.json
# Configuration saved in ./checkpoints/checkpoint-1100/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1100/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-100] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-1200
# Configuration saved in ./checkpoints/checkpoint-1200/config.json
# Configuration saved in ./checkpoints/checkpoint-1200/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1200/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-200] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-1300
# Configuration saved in ./checkpoints/checkpoint-1300/config.json
# Configuration saved in ./checkpoints/checkpoint-1300/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1300/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-300] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-1400
# Configuration saved in ./checkpoints/checkpoint-1400/config.json
# Configuration saved in ./checkpoints/checkpoint-1400/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1400/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-400] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-1500
# Configuration saved in ./checkpoints/checkpoint-1500/config.json
# Configuration saved in ./checkpoints/checkpoint-1500/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1500/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-1600
# Configuration saved in ./checkpoints/checkpoint-1600/config.json
# Configuration saved in ./checkpoints/checkpoint-1600/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1600/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-600] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-1700
# Configuration saved in ./checkpoints/checkpoint-1700/config.json
# Configuration saved in ./checkpoints/checkpoint-1700/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1700/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-700] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-1800
# Configuration saved in ./checkpoints/checkpoint-1800/config.json
# Configuration saved in ./checkpoints/checkpoint-1800/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1800/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-800] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-1900
# Configuration saved in ./checkpoints/checkpoint-1900/config.json
# Configuration saved in ./checkpoints/checkpoint-1900/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-1900/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-900] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2000
# Configuration saved in ./checkpoints/checkpoint-2000/config.json
# Configuration saved in ./checkpoints/checkpoint-2000/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2000/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2100
# Configuration saved in ./checkpoints/checkpoint-2100/config.json
# Configuration saved in ./checkpoints/checkpoint-2100/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2100/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1100] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2200
# Configuration saved in ./checkpoints/checkpoint-2200/config.json
# Configuration saved in ./checkpoints/checkpoint-2200/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2200/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1200] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2300
# Configuration saved in ./checkpoints/checkpoint-2300/config.json
# Configuration saved in ./checkpoints/checkpoint-2300/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2300/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1300] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2400
# Configuration saved in ./checkpoints/checkpoint-2400/config.json
# Configuration saved in ./checkpoints/checkpoint-2400/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2400/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1400] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2500
# Configuration saved in ./checkpoints/checkpoint-2500/config.json
# Configuration saved in ./checkpoints/checkpoint-2500/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2500/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2600
# Configuration saved in ./checkpoints/checkpoint-2600/config.json
# Configuration saved in ./checkpoints/checkpoint-2600/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2600/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1600] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2700
# Configuration saved in ./checkpoints/checkpoint-2700/config.json
# Configuration saved in ./checkpoints/checkpoint-2700/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2700/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1700] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2800
# Configuration saved in ./checkpoints/checkpoint-2800/config.json
# Configuration saved in ./checkpoints/checkpoint-2800/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2800/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1800] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-2900
# Configuration saved in ./checkpoints/checkpoint-2900/config.json
# Configuration saved in ./checkpoints/checkpoint-2900/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-2900/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-1900] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3000
# Configuration saved in ./checkpoints/checkpoint-3000/config.json
# Configuration saved in ./checkpoints/checkpoint-3000/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3000/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3100
# Configuration saved in ./checkpoints/checkpoint-3100/config.json
# Configuration saved in ./checkpoints/checkpoint-3100/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3100/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2100] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3200
# Configuration saved in ./checkpoints/checkpoint-3200/config.json
# Configuration saved in ./checkpoints/checkpoint-3200/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3200/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2200] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3300
# Configuration saved in ./checkpoints/checkpoint-3300/config.json
# Configuration saved in ./checkpoints/checkpoint-3300/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3300/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2300] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3400
# Configuration saved in ./checkpoints/checkpoint-3400/config.json
# Configuration saved in ./checkpoints/checkpoint-3400/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3400/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2400] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3500
# Configuration saved in ./checkpoints/checkpoint-3500/config.json
# Configuration saved in ./checkpoints/checkpoint-3500/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3500/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3600
# Configuration saved in ./checkpoints/checkpoint-3600/config.json
# Configuration saved in ./checkpoints/checkpoint-3600/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3600/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2600] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3700
# Configuration saved in ./checkpoints/checkpoint-3700/config.json
# Configuration saved in ./checkpoints/checkpoint-3700/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3700/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2700] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3800
# Configuration saved in ./checkpoints/checkpoint-3800/config.json
# Configuration saved in ./checkpoints/checkpoint-3800/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3800/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2800] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-3900
# Configuration saved in ./checkpoints/checkpoint-3900/config.json
# Configuration saved in ./checkpoints/checkpoint-3900/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-3900/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-2900] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4000
# Configuration saved in ./checkpoints/checkpoint-4000/config.json
# Configuration saved in ./checkpoints/checkpoint-4000/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4000/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4100
# Configuration saved in ./checkpoints/checkpoint-4100/config.json
# Configuration saved in ./checkpoints/checkpoint-4100/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4100/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3100] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4200
# Configuration saved in ./checkpoints/checkpoint-4200/config.json
# Configuration saved in ./checkpoints/checkpoint-4200/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4200/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3200] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4300
# Configuration saved in ./checkpoints/checkpoint-4300/config.json
# Configuration saved in ./checkpoints/checkpoint-4300/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4300/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3300] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4400
# Configuration saved in ./checkpoints/checkpoint-4400/config.json
# Configuration saved in ./checkpoints/checkpoint-4400/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4400/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3400] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4500
# Configuration saved in ./checkpoints/checkpoint-4500/config.json
# Configuration saved in ./checkpoints/checkpoint-4500/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4500/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4600
# Configuration saved in ./checkpoints/checkpoint-4600/config.json
# Configuration saved in ./checkpoints/checkpoint-4600/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4600/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3600] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4700
# Configuration saved in ./checkpoints/checkpoint-4700/config.json
# Configuration saved in ./checkpoints/checkpoint-4700/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4700/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3700] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4800
# Configuration saved in ./checkpoints/checkpoint-4800/config.json
# Configuration saved in ./checkpoints/checkpoint-4800/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4800/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3800] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-4900
# Configuration saved in ./checkpoints/checkpoint-4900/config.json
# Configuration saved in ./checkpoints/checkpoint-4900/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-4900/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-3900] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5000
# Configuration saved in ./checkpoints/checkpoint-5000/config.json
# Configuration saved in ./checkpoints/checkpoint-5000/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5000/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5100
# Configuration saved in ./checkpoints/checkpoint-5100/config.json
# Configuration saved in ./checkpoints/checkpoint-5100/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5100/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4100] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5200
# Configuration saved in ./checkpoints/checkpoint-5200/config.json
# Configuration saved in ./checkpoints/checkpoint-5200/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5200/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4200] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5300
# Configuration saved in ./checkpoints/checkpoint-5300/config.json
# Configuration saved in ./checkpoints/checkpoint-5300/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5300/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4300] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5400
# Configuration saved in ./checkpoints/checkpoint-5400/config.json
# Configuration saved in ./checkpoints/checkpoint-5400/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5400/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4400] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5500
# Configuration saved in ./checkpoints/checkpoint-5500/config.json
# Configuration saved in ./checkpoints/checkpoint-5500/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5500/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5600
# Configuration saved in ./checkpoints/checkpoint-5600/config.json
# Configuration saved in ./checkpoints/checkpoint-5600/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5600/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4600] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5700
# Configuration saved in ./checkpoints/checkpoint-5700/config.json
# Configuration saved in ./checkpoints/checkpoint-5700/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5700/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4700] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5800
# Configuration saved in ./checkpoints/checkpoint-5800/config.json
# Configuration saved in ./checkpoints/checkpoint-5800/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5800/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4800] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-5900
# Configuration saved in ./checkpoints/checkpoint-5900/config.json
# Configuration saved in ./checkpoints/checkpoint-5900/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-5900/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-4900] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6000
# Configuration saved in ./checkpoints/checkpoint-6000/config.json
# Configuration saved in ./checkpoints/checkpoint-6000/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6000/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6100
# Configuration saved in ./checkpoints/checkpoint-6100/config.json
# Configuration saved in ./checkpoints/checkpoint-6100/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6100/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5100] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6200
# Configuration saved in ./checkpoints/checkpoint-6200/config.json
# Configuration saved in ./checkpoints/checkpoint-6200/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6200/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5200] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6300
# Configuration saved in ./checkpoints/checkpoint-6300/config.json
# Configuration saved in ./checkpoints/checkpoint-6300/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6300/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5300] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6400
# Configuration saved in ./checkpoints/checkpoint-6400/config.json
# Configuration saved in ./checkpoints/checkpoint-6400/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6400/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5400] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6500
# Configuration saved in ./checkpoints/checkpoint-6500/config.json
# Configuration saved in ./checkpoints/checkpoint-6500/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6500/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6600
# Configuration saved in ./checkpoints/checkpoint-6600/config.json
# Configuration saved in ./checkpoints/checkpoint-6600/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6600/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5600] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6700
# Configuration saved in ./checkpoints/checkpoint-6700/config.json
# Configuration saved in ./checkpoints/checkpoint-6700/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6700/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5700] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6800
# Configuration saved in ./checkpoints/checkpoint-6800/config.json
# Configuration saved in ./checkpoints/checkpoint-6800/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6800/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5800] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-6900
# Configuration saved in ./checkpoints/checkpoint-6900/config.json
# Configuration saved in ./checkpoints/checkpoint-6900/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-6900/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-5900] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7000
# Configuration saved in ./checkpoints/checkpoint-7000/config.json
# Configuration saved in ./checkpoints/checkpoint-7000/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7000/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7100
# Configuration saved in ./checkpoints/checkpoint-7100/config.json
# Configuration saved in ./checkpoints/checkpoint-7100/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7100/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6100] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7200
# Configuration saved in ./checkpoints/checkpoint-7200/config.json
# Configuration saved in ./checkpoints/checkpoint-7200/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7200/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6200] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7300
# Configuration saved in ./checkpoints/checkpoint-7300/config.json
# Configuration saved in ./checkpoints/checkpoint-7300/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7300/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6300] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7400
# Configuration saved in ./checkpoints/checkpoint-7400/config.json
# Configuration saved in ./checkpoints/checkpoint-7400/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7400/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6400] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7500
# Configuration saved in ./checkpoints/checkpoint-7500/config.json
# Configuration saved in ./checkpoints/checkpoint-7500/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7500/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7600
# Configuration saved in ./checkpoints/checkpoint-7600/config.json
# Configuration saved in ./checkpoints/checkpoint-7600/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7600/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6600] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7700
# Configuration saved in ./checkpoints/checkpoint-7700/config.json
# Configuration saved in ./checkpoints/checkpoint-7700/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7700/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6700] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7800
# Configuration saved in ./checkpoints/checkpoint-7800/config.json
# Configuration saved in ./checkpoints/checkpoint-7800/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7800/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6800] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-7900
# Configuration saved in ./checkpoints/checkpoint-7900/config.json
# Configuration saved in ./checkpoints/checkpoint-7900/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-7900/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-6900] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-8000
# Configuration saved in ./checkpoints/checkpoint-8000/config.json
# Configuration saved in ./checkpoints/checkpoint-8000/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-8000/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-8100
# Configuration saved in ./checkpoints/checkpoint-8100/config.json
# Configuration saved in ./checkpoints/checkpoint-8100/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-8100/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-7100] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-8200
# Configuration saved in ./checkpoints/checkpoint-8200/config.json
# Configuration saved in ./checkpoints/checkpoint-8200/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-8200/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-7200] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-8300
# Configuration saved in ./checkpoints/checkpoint-8300/config.json
# Configuration saved in ./checkpoints/checkpoint-8300/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-8300/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-7300] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-8400
# Configuration saved in ./checkpoints/checkpoint-8400/config.json
# Configuration saved in ./checkpoints/checkpoint-8400/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-8400/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-7400] due to args.save_total_limit
# Saving model checkpoint to ./checkpoints/checkpoint-8500
# Configuration saved in ./checkpoints/checkpoint-8500/config.json
# Configuration saved in ./checkpoints/checkpoint-8500/generation_config.json
# Model weights saved in ./checkpoints/checkpoint-8500/pytorch_model.bin
# Deleting older checkpoint [checkpoints/checkpoint-7500] due to args.save_total_limit

# %%
trainer.push_to_hub()
